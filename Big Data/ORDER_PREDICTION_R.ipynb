# %%
# Load required libraries
library(dplyr)
library(xts)
library(zoo)
library(ggplot2)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Error: package or namespace load failed for 'dplyr' in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]):
#  there is no package called 'lifecycle'
# Traceback:
#
# 1. library(dplyr)
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps, exclude, include.only)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# ...

# %%
url <- "quantity_sums.csv"
data <- read.csv(url)

# %%
str(data)
# Out:
# 'data.frame':	13392 obs. of  4 variables:
#  $ FOLIO_NUMBER           : num  20210927 20210927 20210927 20210927 20210927 ...
#  $ CUSTOMER_NUMBER        : int  3 3 3 5 6 7 7 8 8 8 ...
#  $ TERMINAL_PRODUCT_NUMBER: int  4 7 8 7 7 4 7 4 7 10 ...
#  $ ORDERED_QUANTITY       : int  83100 273100 57600 95000 44000 6000 25000 26000 325000 35500 ...

# %%
unique_customers <- unique(data$CUSTOMER_NUMBER)
print(sort(unique_customers))
# Out:
#  [1]  1  2  3  5  6  7  8  9 12 13 14 15 16 17 18 19 20

# %%
data$FOLIO_NUMBER <- as.Date(as.character(data$FOLIO_NUMBER), format = "%Y%m%d")

# %% [markdown]
# <H1>Per Products</H1>

# %%
data_product_number_4 <- subset(data, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_product_number_7 <- subset(data, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)
data_product_number_8 <- subset(data, TERMINAL_PRODUCT_NUMBER == 8, select = -TERMINAL_PRODUCT_NUMBER)
data_product_number_9 <- subset(data, TERMINAL_PRODUCT_NUMBER == 9, select = -TERMINAL_PRODUCT_NUMBER)
data_product_number_10 <- subset(data, TERMINAL_PRODUCT_NUMBER == 10, select = -TERMINAL_PRODUCT_NUMBER)
data_product_number_11 <- subset(data, TERMINAL_PRODUCT_NUMBER == 11, select = -TERMINAL_PRODUCT_NUMBER)
data_product_number_12 <- subset(data, TERMINAL_PRODUCT_NUMBER == 12, select = -TERMINAL_PRODUCT_NUMBER)
data_product_number_13 <- subset(data, TERMINAL_PRODUCT_NUMBER == 13, select = -TERMINAL_PRODUCT_NUMBER)

# %% [markdown]
# TERMINAL_PRODUCT_NUMBER: 4

# %%
xts_data <- xts(data_product_number_4$ORDERED_QUANTITY, order.by = data_product_number_4$FOLIO_NUMBER)
plot(xts_data)
# Out:
# plot without title

# %%
xts_data <- xts(data_product_number_4$ORDERED_QUANTITY, order.by = data_product_number_4$FOLIO_NUMBER)
product_data_monthly <- apply.monthly(xts_data, FUN = "sum")
plot(product_data_monthly)
# Out:
# plot without title

# %% [markdown]
# TERMINAL_PRODUCT_NUMBER: 7

# %%
xts_data <- xts(data_product_number_7$ORDERED_QUANTITY, order.by = data_product_number_7$FOLIO_NUMBER)
plot(xts_data)
# Out:
# plot without title

# %%
xts_data <- xts(data_product_number_7$ORDERED_QUANTITY, order.by = data_product_number_7$FOLIO_NUMBER)
product_data_monthly <- apply.monthly(xts_data, FUN = "sum")
plot(product_data_monthly)
# Out:
# plot without title

# %% [markdown]
# TERMINAL_PRODUCT_NUMBER: 8

# %%
xts_data <- xts(data_product_number_8$ORDERED_QUANTITY, order.by = data_product_number_8$FOLIO_NUMBER)
plot(xts_data,type="o")
# Out:
# plot without title

# %%
xts_data <- xts(data_product_number_8$ORDERED_QUANTITY, order.by = data_product_number_8$FOLIO_NUMBER)
product_data_monthly <- apply.monthly(xts_data, FUN = "sum")
plot(product_data_monthly)
# Out:
# plot without title

# %% [markdown]
# TERMINAL_PRODUCT_NUMBER: 9

# %%
xts_data <- xts(data_product_number_9$ORDERED_QUANTITY, order.by = data_product_number_9$FOLIO_NUMBER)
plot(xts_data)
# Out:
# plot without title

# %%
xts_data <- xts(data_product_number_9$ORDERED_QUANTITY, order.by = data_product_number_9$FOLIO_NUMBER)
product_data_monthly <- apply.monthly(xts_data, FUN = "sum")
plot(product_data_monthly)
# Out:
# plot without title

# %% [markdown]
# TERMINAL_PRODUCT_NUMBER: 10

# %%
xts_data <- xts(data_product_number_10$ORDERED_QUANTITY, order.by = data_product_number_10$FOLIO_NUMBER)
plot(xts_data)
# Out:
# plot without title

# %%
xts_data <- xts(data_product_number_10$ORDERED_QUANTITY, order.by = data_product_number_10$FOLIO_NUMBER)
product_data_monthly <- apply.monthly(xts_data, FUN = "sum")
plot(product_data_monthly)
# Out:
# plot without title

# %% [markdown]
# TERMINAL_PRODUCT_NUMBER: 11

# %%
xts_data <- xts(data_product_number_11$ORDERED_QUANTITY, order.by = data_product_number_11$FOLIO_NUMBER)
plot(xts_data)
# Out:
# plot without title

# %%
xts_data <- xts(data_product_number_11$ORDERED_QUANTITY, order.by = data_product_number_11$FOLIO_NUMBER)
product_data_monthly <- apply.monthly(xts_data, FUN = "sum")
plot(product_data_monthly)
# Out:
# plot without title

# %% [markdown]
# TERMINAL_PRODUCT_NUMBER: 12

# %%
xts_data <- xts(data_product_number_12$ORDERED_QUANTITY, order.by = data_product_number_12$FOLIO_NUMBER)
plot(xts_data)
# Out:
# plot without title

# %%
xts_data <- xts(data_product_number_12$ORDERED_QUANTITY, order.by = data_product_number_12$FOLIO_NUMBER)
product_data_monthly <- apply.monthly(xts_data, FUN = "sum")
plot(product_data_monthly)
# Out:
# plot without title

# %% [markdown]
# TERMINAL_PRODUCT_NUMBER: 13

# %%
xts_data <- xts(data_product_number_13$ORDERED_QUANTITY, order.by = data_product_number_13$FOLIO_NUMBER)
plot(xts_data)
# Out:
# plot without title

# %%
xts_data <- xts(data_product_number_13$ORDERED_QUANTITY, order.by = data_product_number_13$FOLIO_NUMBER)
product_data_monthly <- apply.monthly(xts_data, FUN = "sum")
plot(product_data_monthly)
# Out:
# plot without title

# %% [markdown]
# <H1>Per Costumers</H1>

# %%
data_customer_1 <- subset(data, CUSTOMER_NUMBER == 1, select = -CUSTOMER_NUMBER)
data_customer_2 <- subset(data, CUSTOMER_NUMBER == 2, select = -CUSTOMER_NUMBER)
data_customer_3 <- subset(data, CUSTOMER_NUMBER == 3, select = -CUSTOMER_NUMBER)
data_customer_5 <- subset(data, CUSTOMER_NUMBER == 5, select = -CUSTOMER_NUMBER)
data_customer_6 <- subset(data, CUSTOMER_NUMBER == 6, select = -CUSTOMER_NUMBER)
data_customer_7 <- subset(data, CUSTOMER_NUMBER == 7, select = -CUSTOMER_NUMBER)
data_customer_8 <- subset(data, CUSTOMER_NUMBER == 8, select = -CUSTOMER_NUMBER)
data_customer_9 <- subset(data, CUSTOMER_NUMBER == 9, select = -CUSTOMER_NUMBER)
data_customer_12 <- subset(data, CUSTOMER_NUMBER == 12, select = -CUSTOMER_NUMBER)
data_customer_13 <- subset(data, CUSTOMER_NUMBER == 13, select = -CUSTOMER_NUMBER)
data_customer_14 <- subset(data, CUSTOMER_NUMBER == 14, select = -CUSTOMER_NUMBER)
data_customer_15 <- subset(data, CUSTOMER_NUMBER == 15, select = -CUSTOMER_NUMBER)
data_customer_16 <- subset(data, CUSTOMER_NUMBER == 16, select = -CUSTOMER_NUMBER)
data_customer_17 <- subset(data, CUSTOMER_NUMBER == 17, select = -CUSTOMER_NUMBER)
data_customer_18 <- subset(data, CUSTOMER_NUMBER == 18, select = -CUSTOMER_NUMBER)
data_customer_19 <- subset(data, CUSTOMER_NUMBER == 19, select = -CUSTOMER_NUMBER)

# %%
unique_TERMINAL_PRODUCT_NUMBER_customer_1 <- unique(data_customer_1$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_1))

unique_TERMINAL_PRODUCT_NUMBER_customer_2 <- unique(data_customer_2$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_2))

unique_TERMINAL_PRODUCT_NUMBER_customer_3 <- unique(data_customer_3$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_3))

unique_TERMINAL_PRODUCT_NUMBER_customer_5 <- unique(data_customer_5$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_5))

unique_TERMINAL_PRODUCT_NUMBER_customer_6 <- unique(data_customer_6$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_6))

unique_TERMINAL_PRODUCT_NUMBER_customer_7 <- unique(data_customer_7$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_7))

unique_TERMINAL_PRODUCT_NUMBER_customer_8 <- unique(data_customer_8$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_8))

unique_TERMINAL_PRODUCT_NUMBER_customer_9 <- unique(data_customer_9$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_9))

unique_TERMINAL_PRODUCT_NUMBER_customer_12 <- unique(data_customer_12$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_12))

unique_TERMINAL_PRODUCT_NUMBER_customer_13 <- unique(data_customer_13$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_13))

unique_TERMINAL_PRODUCT_NUMBER_customer_14 <- unique(data_customer_14$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_14))

unique_TERMINAL_PRODUCT_NUMBER_customer_15 <- unique(data_customer_15$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_15))

unique_TERMINAL_PRODUCT_NUMBER_customer_16 <- unique(data_customer_16$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_16))

unique_TERMINAL_PRODUCT_NUMBER_customer_17 <- unique(data_customer_17$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_17))

unique_TERMINAL_PRODUCT_NUMBER_customer_18 <- unique(data_customer_18$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_18))

unique_TERMINAL_PRODUCT_NUMBER_customer_19 <- unique(data_customer_19$TERMINAL_PRODUCT_NUMBER)
print(sort(unique_TERMINAL_PRODUCT_NUMBER_customer_19))
# Out:
# [1] 4 7
# [1] 4 7
# [1]  4  7  8  9 10 11
# [1]  4  7 10 12 13
# [1] 4 7
# [1] 4 7
# [1]  4  7 10 11
# [1] 4 7
# [1] 4 7
# [1] 4 7
# [1] 4 7
# [1] 4 7
# [1] 4 7
# [1] 4 7
# [1] 4 7
# [1] 4 7

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 1</h3>

# %%
data_customer_1_product_number_4 <- subset(data_customer_1, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_1_product_number_7 <- subset(data_customer_1, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data <- xts(data_customer_1_product_number_4$ORDERED_QUANTITY, order.by = data_customer_1_product_number_4$FOLIO_NUMBER)
plot(xts_data,type="o")
# Out:
# plot without title

# %%
xts_data <- xts(data_customer_1_product_number_7$ORDERED_QUANTITY, order.by = data_customer_1_product_number_7$FOLIO_NUMBER)
plot(xts_data,type="o")
# Out:
# plot without title

# %%
xts_data <- xts(data_customer_1_product_number_7$ORDERED_QUANTITY, order.by = data_customer_1_product_number_7$FOLIO_NUMBER)
product_data_monthly <- apply.monthly(xts_data, FUN = "sum")
plot(product_data_monthly,type="o")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 2</h3>

# %%
data_customer_2_product_number_4 <- subset(data_customer_2, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_2_product_number_7 <- subset(data_customer_2, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_2_product_number_4 <- xts(data_customer_2_product_number_4$ORDERED_QUANTITY, order.by = data_customer_2_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_2_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 2")
# Out:
# plot without title

# %%
xts_data_customer_2_product_number_7 <- xts(data_customer_2_product_number_7$ORDERED_QUANTITY, order.by = data_customer_2_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_2_product_number_7, main = "Product Number 7 Orders for Customer 2")
# Out:
# plot without title

# %%
product_data_monthly_customer_2 <- apply.monthly(xts_data_customer_2_product_number_7, FUN = "sum")
plot(product_data_monthly_customer_2, type = "o", main = "Monthly Product Number 7 Orders for Customer 2")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 3</h3>

# %%
data_customer_3_product_number_4 <- subset(data_customer_3, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_3_product_number_7 <- subset(data_customer_3, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_3_product_number_8 <- subset(data_customer_3, TERMINAL_PRODUCT_NUMBER == 8, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_3_product_number_9 <- subset(data_customer_3, TERMINAL_PRODUCT_NUMBER == 9, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_3_product_number_10 <- subset(data_customer_3, TERMINAL_PRODUCT_NUMBER == 10, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_3_product_number_11 <- subset(data_customer_3, TERMINAL_PRODUCT_NUMBER == 11, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_3_product_number_4 <- xts(data_customer_3_product_number_4$ORDERED_QUANTITY, order.by = data_customer_3_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_3_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 3")
# Out:
# plot without title

# %%
product_data_monthly_customer_2 <- apply.monthly(xts_data_customer_3_product_number_4, FUN = "sum")
plot(product_data_monthly_customer_2, type = "o", main = "Monthly Product Number 4 Orders for Customer 3")
# Out:
# plot without title

# %%
xts_data_customer_3_product_number_7 <- xts(data_customer_3_product_number_7$ORDERED_QUANTITY, order.by = data_customer_3_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_3_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 3")
# Out:
# plot without title

# %%
xts_data_customer_3_product_number_8 <- xts(data_customer_3_product_number_8$ORDERED_QUANTITY, order.by = data_customer_3_product_number_8$FOLIO_NUMBER)
plot(xts_data_customer_3_product_number_8, type = "o", main = "Product Number 8 Orders for Customer 3")
# Out:
# plot without title

# %%
xts_data_customer_3_product_number_9 <- xts(data_customer_3_product_number_9$ORDERED_QUANTITY, order.by = data_customer_3_product_number_9$FOLIO_NUMBER)
plot(xts_data_customer_3_product_number_9, type = "o", main = "Product Number 9 Orders for Customer 3")
# Out:
# plot without title

# %%
xts_data_customer_3_product_number_10 <- xts(data_customer_3_product_number_10$ORDERED_QUANTITY, order.by = data_customer_3_product_number_10$FOLIO_NUMBER)
plot(xts_data_customer_3_product_number_10, type = "o", main = "Product Number 10 Orders for Customer 3")
# Out:
# plot without title

# %%
xts_data_customer_3_product_number_11 <- xts(data_customer_3_product_number_11$ORDERED_QUANTITY, order.by = data_customer_3_product_number_11$FOLIO_NUMBER)
plot(xts_data_customer_3_product_number_11, type = "o", main = "Product Number 11 Orders for Customer 3")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 5</h3>

# %%
data_customer_5_product_number_4 <- subset(data_customer_5, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_5_product_number_7 <- subset(data_customer_5, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_5_product_number_10 <- subset(data_customer_5, TERMINAL_PRODUCT_NUMBER == 10, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_5_product_number_12 <- subset(data_customer_5, TERMINAL_PRODUCT_NUMBER == 12, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_5_product_number_13 <- subset(data_customer_5, TERMINAL_PRODUCT_NUMBER == 13, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_5_product_number_4 <- xts(data_customer_5_product_number_4$ORDERED_QUANTITY, order.by = data_customer_5_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_5_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 5")
# Out:
# plot without title

# %%
xts_data_customer_5_product_number_7 <- xts(data_customer_5_product_number_7$ORDERED_QUANTITY, order.by = data_customer_5_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_5_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 5")
# Out:
# plot without title

# %%
xts_data_customer_5_product_number_10 <- xts(data_customer_5_product_number_10$ORDERED_QUANTITY, order.by = data_customer_5_product_number_10$FOLIO_NUMBER)
plot(xts_data_customer_5_product_number_10, type = "o", main = "Product Number 10 Orders for Customer 5")
# Out:
# plot without title

# %%
xts_data_customer_5_product_number_12 <- xts(data_customer_5_product_number_12$ORDERED_QUANTITY, order.by = data_customer_5_product_number_12$FOLIO_NUMBER)
plot(xts_data_customer_5_product_number_12, type = "o", main = "Product Number 12 Orders for Customer 5")
# Out:
# plot without title

# %%
xts_data_customer_5_product_number_13 <- xts(data_customer_5_product_number_13$ORDERED_QUANTITY, order.by = data_customer_5_product_number_13$FOLIO_NUMBER)
plot(xts_data_customer_5_product_number_13, type = "o", main = "Product Number 13 Orders for Customer 5")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 6</h3>

# %%
data_customer_6_product_number_4 <- subset(data_customer_6, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_6_product_number_7 <- subset(data_customer_6, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_6_product_number_4 <- xts(data_customer_6_product_number_4$ORDERED_QUANTITY, order.by = data_customer_6_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_6_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 6")
# Out:
# plot without title

# %%
xts_data_customer_6_product_number_7 <- xts(data_customer_6_product_number_7$ORDERED_QUANTITY, order.by = data_customer_6_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_6_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 6")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 7 </h3>

# %%
data_customer_7_product_number_4 <- subset(data_customer_7, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_7_product_number_7 <- subset(data_customer_7, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_7_product_number_4 <- xts(data_customer_7_product_number_4$ORDERED_QUANTITY, order.by = data_customer_7_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_7_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 7")
# Out:
# plot without title

# %%
xts_data_customer_7_product_number_7 <- xts(data_customer_7_product_number_7$ORDERED_QUANTITY, order.by = data_customer_7_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_7_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 7")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 8 </h3>

# %%
data_customer_8_product_number_4 <- subset(data_customer_8, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_8_product_number_7 <- subset(data_customer_8, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_8_product_number_10 <- subset(data_customer_8, TERMINAL_PRODUCT_NUMBER == 10, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_8_product_number_11 <- subset(data_customer_8, TERMINAL_PRODUCT_NUMBER == 11, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_8_product_number_4 <- xts(data_customer_8_product_number_4$ORDERED_QUANTITY, order.by = data_customer_8_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_8_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 8")
# Out:
# plot without title

# %%
xts_data_customer_8_product_number_7 <- xts(data_customer_8_product_number_7$ORDERED_QUANTITY, order.by = data_customer_8_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_8_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 8")
# Out:
# plot without title

# %%
xts_data_customer_8_product_number_10 <- xts(data_customer_8_product_number_10$ORDERED_QUANTITY, order.by = data_customer_8_product_number_10$FOLIO_NUMBER)
plot(xts_data_customer_8_product_number_10, type = "o", main = "Product Number 10 Orders for Customer 8")
# Out:
# plot without title

# %%
xts_data_customer_8_product_number_11 <- xts(data_customer_8_product_number_11$ORDERED_QUANTITY, order.by = data_customer_8_product_number_11$FOLIO_NUMBER)
plot(xts_data_customer_8_product_number_11, type = "o", main = "Product Number 11 Orders for Customer 8")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 9 </h3>

# %%
data_customer_9_product_number_4 <- subset(data_customer_9, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_9_product_number_7 <- subset(data_customer_9, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_9_product_number_4 <- xts(data_customer_9_product_number_4$ORDERED_QUANTITY, order.by = data_customer_9_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_9_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 9")
# Out:
# plot without title

# %%
xts_data_customer_9_product_number_7 <- xts(data_customer_9_product_number_7$ORDERED_QUANTITY, order.by = data_customer_9_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_9_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 9")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 12 </h3>

# %%
data_customer_12_product_number_4 <- subset(data_customer_12, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_12_product_number_7 <- subset(data_customer_12, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_12_product_number_4 <- xts(data_customer_12_product_number_4$ORDERED_QUANTITY, order.by = data_customer_12_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_12_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 12")
# Out:
# plot without title

# %%
xts_data_customer_12_product_number_7 <- xts(data_customer_12_product_number_7$ORDERED_QUANTITY, order.by = data_customer_12_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_12_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 12")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 13 </h3>

# %%
data_customer_13_product_number_4 <- subset(data_customer_13, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_13_product_number_7 <- subset(data_customer_13, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_13_product_number_4 <- xts(data_customer_13_product_number_4$ORDERED_QUANTITY, order.by = data_customer_13_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_13_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 13")
# Out:
# plot without title

# %%
xts_data_customer_13_product_number_7 <- xts(data_customer_13_product_number_7$ORDERED_QUANTITY, order.by = data_customer_13_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_13_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 13")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 14 </h3>

# %%
data_customer_14_product_number_4 <- subset(data_customer_14, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_14_product_number_7 <- subset(data_customer_14, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_14_product_number_4 <- xts(data_customer_14_product_number_4$ORDERED_QUANTITY, order.by = data_customer_14_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_14_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 14")
# Out:
# plot without title

# %%
xts_data_customer_14_product_number_7 <- xts(data_customer_14_product_number_7$ORDERED_QUANTITY, order.by = data_customer_14_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_14_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 14")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 15 </h3>

# %%
data_customer_15_product_number_4 <- subset(data_customer_15, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_15_product_number_7 <- subset(data_customer_15, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_15_product_number_4 <- xts(data_customer_15_product_number_4$ORDERED_QUANTITY, order.by = data_customer_15_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_15_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 15")
# Out:
# plot without title

# %%
xts_data_customer_15_product_number_7 <- xts(data_customer_15_product_number_7$ORDERED_QUANTITY, order.by = data_customer_15_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_15_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 15")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 16 </h3>

# %%
data_customer_16_product_number_4 <- subset(data_customer_16, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_16_product_number_7 <- subset(data_customer_16, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_16_product_number_4 <- xts(data_customer_16_product_number_4$ORDERED_QUANTITY, order.by = data_customer_16_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_16_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 16")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 17 </h3>

# %%
data_customer_17_product_number_4 <- subset(data_customer_17, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_17_product_number_7 <- subset(data_customer_17, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_17_product_number_4 <- xts(data_customer_17_product_number_4$ORDERED_QUANTITY, order.by = data_customer_17_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_17_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 17")
# Out:
# plot without title

# %%
xts_data_customer_17_product_number_7 <- xts(data_customer_17_product_number_7$ORDERED_QUANTITY, order.by = data_customer_17_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_17_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 17")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 18 </h3>

# %%
data_customer_18_product_number_4 <- subset(data_customer_18, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_18_product_number_7 <- subset(data_customer_18, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_18_product_number_4 <- xts(data_customer_18_product_number_4$ORDERED_QUANTITY, order.by = data_customer_18_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_18_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 18")
# Out:
# plot without title

# %%
xts_data_customer_18_product_number_7 <- xts(data_customer_18_product_number_7$ORDERED_QUANTITY, order.by = data_customer_18_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_18_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 18")
# Out:
# plot without title

# %% [markdown]
# <h3>CUSTOMER_NUMBER : 19 </h3>

# %%
data_customer_19_product_number_4 <- subset(data_customer_19, TERMINAL_PRODUCT_NUMBER == 4, select = -TERMINAL_PRODUCT_NUMBER)
data_customer_19_product_number_7 <- subset(data_customer_19, TERMINAL_PRODUCT_NUMBER == 7, select = -TERMINAL_PRODUCT_NUMBER)

# %%
xts_data_customer_19_product_number_4 <- xts(data_customer_19_product_number_4$ORDERED_QUANTITY, order.by = data_customer_19_product_number_4$FOLIO_NUMBER)
plot(xts_data_customer_19_product_number_4, type = "o", main = "Product Number 4 Orders for Customer 19")
# Out:
# plot without title

# %%
xts_data_customer_19_product_number_7 <- xts(data_customer_19_product_number_7$ORDERED_QUANTITY, order.by = data_customer_19_product_number_7$FOLIO_NUMBER)
plot(xts_data_customer_19_product_number_7, type = "o", main = "Product Number 7 Orders for Customer 19")
# Out:
# plot without title

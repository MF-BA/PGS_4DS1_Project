# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
INJECTOR_HISTORY = pd.read_excel("INJECTOR_HISTORY.xls")
METER_HISTORY = pd.read_excel("METER_HISTORY.xls")
ORDER_RECIPE1 = pd.read_excel("ORDER_RECIPE1.xls")
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
INJECTOR_HISTORY.head()
# Out:
#    METER_PRESET_CODE PRESET_CODE INJECTOR_CODE  FOLIO_NUMBER  TOTALIZER  \
# 0                NaN     FIQ_201       INJ_201      20210927      20513
# 1                NaN     FIQ_201       INJ_201      20210928      20523
# 2                NaN     FIQ_201       INJ_201      20210929      20547
# 3                NaN     FIQ_201       INJ_201      20210930      20563
# 4                NaN     FIQ_201       INJ_201      20211001      20588
#
#    TERMINAL_PRODUCT_NUMBER  METER_CODE  THRUPUT  UNACCOUNTED  PRODUCT_THRUPUT  \
# 0                        8         NaN        7            0            25990
# 1                        8         NaN       10            0            33973
# 2                        8         NaN       23            0            78211
# 3                        8         NaN       16            0            53963
# 4                        8         NaN       25            0            83864
#
# ...

# %%
INJECTOR_HISTORY["PRESET_CODE"].unique()
#INJECTOR_HISTORY["UNACCOUNTED"].describe()
# Out:
# array(['FIQ_201', 'FIQ_202', 'FIQ_203', 'FIQ_301', 'FIQ_302', 'FIQ_303',
#        'FIQ_401', 'FIQ_402', 'FIQ_403', 'FIQ_501', 'FIQ_502', 'FIQ_503'],
#       dtype=object)

# %%
METER_HISTORY.head()
# Out:
#   PRESET_CODE  FOLIO_NUMBER METER_CODE  GROSS_TOTALIZER  \
# 0     FIQ_201      20210927    MTR_201        468526870
# 1     FIQ_201      20210928    MTR_201        468989595
# 2     FIQ_201      20210929    MTR_201        469520570
# 3     FIQ_201      20210930    MTR_201        470083808
# 4     FIQ_201      20211001    MTR_201        470383616
#
#    TERMINAL_PRODUCT_NUMBER  GROSS_THRUPUT  NET_TOTALIZER  GROSS_UNACCOUNTED  \
# 0                        7         337871      465948755               7998
# 1                        7         448730      466407233              13995
# 2                        7         530971      466933319                  4
# 3                        7         563237      467490763                  1
# 4                        7         299805      467787524                  3
#
#    NET_THRUPUT  NET_UNACCOUNTED  BOD_GROSS_TOTALIZER  BOD_NET_TOTALIZER  \
# 0       334744             7925            468181001          465606086
# ...

# %%
METER_HISTORY["PRESET_CODE"].unique()
METER_HISTORY["TERMINAL_PRODUCT_NUMBER"].unique()
# Out:
# array([7, 4, 1, 2], dtype=int64)

# %%
ORDER_RECIPE1.head()
# Out:
#    ORDER_ID  COMPARTMENT_ID  ORDER_RECIPE_ID BAY_CODE API_CODE  \
# 0      8320            8342             8343      NaN      54B
# 1      8320            8344             8345      NaN      54B
# 2      8320            8346             8347      NaN      54B
# 3      8320            8348             8349  BAY_300      54B
# 4      8320            8350             8351      NaN      54B
#
#   INJECTOR_PRESET_CODE  TARE_SCALE_INTERFACE_CODE TANK_CODE  \
# 0                  NaN                        NaN       NaN
# 1                  NaN                        NaN       NaN
# 2                  NaN                        NaN       NaN
# 3                  NaN                        NaN    TK-205
# 4                  NaN                        NaN       NaN
#
#   PRODUCT_GROUP_CODE INJECTOR_CODE  ... COMPARTMENT_CONTAINER_TYPE  \
# 0                DSL           NaN  ...                        NaN
# 1                DSL           NaN  ...                        NaN
# ...
